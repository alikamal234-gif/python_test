# %% [markdown]
# # 🐼 10 Challenges Pandas — Data Scientist & AI Engineer
#
# ## 🎯 Objectif général
#
# Cette série de 10 challenges a pour objectif de maîtriser **Pandas** pour :
#
# - explorer des données ;
# - sélectionner et filtrer des informations ;
# - nettoyer des datasets réels ;
# - transformer les données ;
# - créer de nouvelles variables ;
# - réaliser des analyses statistiques ;
# - regrouper et combiner plusieurs sources de données ;
# - analyser des données temporelles ;
# - préparer les données pour le Machine Learning.
#
# > **Consigne générale :** pour chaque challenge, utilisez principalement Pandas et privilégiez les opérations vectorisées lorsque cela est possible.
#
# ---
#
# # 🟢 Challenge 1 — Découverte et exploration d'un dataset
#
# ## 🎯 Objectif
#
# Découvrir un dataset inconnu et comprendre sa structure.
#
# ## 📂 Dataset : `clients.csv`
#
# ```csv
# client_id,nom,age,sexe,ville,salaire,anciennete
# 1,Ali,25,M,Casablanca,5000,2
# 2,Sara,31,F,Rabat,6500,5
# 3,Yassine,28,M,Marrakech,4500,3
# 4,Salma,35,F,Casablanca,8000,7
# 5,Omar,42,M,Rabat,9000,10
# 6,Nadia,29,F,Tanger,5200,4
# 7,Mehdi,38,M,Casablanca,7500,8
# 8,Hajar,26,F,Marrakech,4800,2
# 9,Adam,45,M,Rabat,10000,12
# 10,Souad,33,F,Tanger,6200,6
# ```
#
# ## 📋 Travail demandé
#
# 1. Charger le fichier CSV avec Pandas.
# 2. Afficher les premières lignes.
# 3. Afficher les dernières lignes.
# 4. Afficher le nombre de lignes et de colonnes.
# 5. Afficher les noms des colonnes.
# 6. Afficher l'index.
# 7. Afficher les types de données.
# 8. Utiliser `info()`.
# 9. Utiliser `describe()`.
# 10. Identifier les colonnes numériques et catégorielles.
# 11. Afficher les valeurs uniques de `ville`.
# 12. Compter le nombre de villes différentes.
# 13. Afficher le nombre de clients par ville.
# 14. Rechercher les valeurs manquantes.
# 15. Formuler quelques observations sur le dataset.
#
# ## 🧠 Notions
#
# `DataFrame`, `Series`, `head()`, `tail()`, `shape`, `columns`, `index`, `dtypes`, `info()`, `describe()`, `unique()`, `nunique()`, `value_counts()`, `isna()`.
#
# ---
#
# # 🟢 Challenge 2 — Sélection et filtrage des données
#
# ## 🎯 Objectif
#
# Extraire précisément les données dont on a besoin.
#
# ## 📂 Dataset : `clients.csv`
#
# Utiliser le même dataset que dans le Challenge 1.
#
# ```csv
# client_id,nom,age,sexe,ville,salaire,anciennete
# 1,Ali,25,M,Casablanca,5000,2
# 2,Sara,31,F,Rabat,6500,5
# 3,Yassine,28,M,Marrakech,4500,3
# 4,Salma,35,F,Casablanca,8000,7
# 5,Omar,42,M,Rabat,9000,10
# 6,Nadia,29,F,Tanger,5200,4
# 7,Mehdi,38,M,Casablanca,7500,8
# 8,Hajar,26,F,Marrakech,4800,2
# 9,Adam,45,M,Rabat,10000,12
# 10,Souad,33,F,Tanger,6200,6
# ```
#
# ## 📋 Travail demandé
#
# 1. Sélectionner la colonne `nom`.
# 2. Sélectionner les colonnes `nom`, `age` et `ville`.
# 3. Sélectionner les trois premières lignes avec `iloc`.
# 4. Sélectionner les clients ayant plus de 30 ans.
# 5. Sélectionner les clients ayant un salaire supérieur à 6 000.
# 6. Sélectionner les clients de Casablanca.
# 7. Sélectionner les femmes ayant plus de 30 ans.
# 8. Sélectionner les clients de Casablanca ou Rabat.
# 9. Utiliser `isin()` pour sélectionner plusieurs villes.
# 10. Utiliser `between()` pour sélectionner les clients âgés de 25 à 35 ans.
# 11. Utiliser `~` pour exclure une ville.
# 12. Extraire une cellule précise avec `loc` ou `iloc`.
#
# ## 🧠 Notions
#
# `[]`, `loc`, `iloc`, filtrage booléen, `&`, `|`, `~`, `isin()`, `between()`.
#
# ---
#
# # 🟠 Challenge 3 — Nettoyage complet des données
#
# ## 🎯 Objectif
#
# Transformer un dataset brut et imparfait en dataset propre et exploitable.
#
# ## 📂 Dataset : `clients_dirty.csv`
#
# ```csv
# client_id,nom,age,sexe,ville,salaire,date_inscription
# 1," Ali ",25,M,"Casablanca",5000,"2026-01-10"
# 2,"Sara",31,F,"Rabat",6500,"2026-01-15"
# 3,"Yassine",28,M,"Marrakech","4500 DH","2026-02-01"
# 4,"Salma",35,F,"casablanca",8000,"2026-02-05"
# 5,"Omar",,M,"Rabat",9000,"2026-02-10"
# 6,"Nadia",29,F," Tanger ",5200,"2026-02-15"
# 7,"Mehdi",38,M,"CASABLANCA",7500,"2026-03-01"
# 8,"Hajar","N/A",F,"Marrakech",4800,"2026-03-05"
# 9,"Adam",45,M,"Rabat",-1000,"2026-03-10"
# 10,"Souad",33,F,"Tanger",6200,"2026-03-15"
# 10,"Souad",33,F,"Tanger",6200,"2026-03-15"
# ```
#
# ## 📋 Travail demandé
#
# 1. Identifier les problèmes présents dans le dataset.
# 2. Rechercher les valeurs manquantes.
# 3. Identifier les doublons.
# 4. Supprimer les doublons.
# 5. Nettoyer les espaces dans les noms.
# 6. Nettoyer les espaces dans les villes.
# 7. Standardiser les noms des villes.
# 8. Transformer `"N/A"` en valeur manquante.
# 9. Convertir `age` en numérique.
# 10. Nettoyer la colonne `salaire`.
# 11. Supprimer `"DH"` de la colonne salaire.
# 12. Transformer `salaire` en numérique.
# 13. Identifier le salaire négatif.
# 14. Traiter cette valeur invalide avec une stratégie pertinente.
# 15. Transformer `date_inscription` en datetime.
# 16. Vérifier les types finaux.
# 17. Vérifier le nombre de lignes après nettoyage.
# 18. Vérifier que le dataset final est cohérent.
#
# ## 🧠 Notions
#
# `isna()`, `notna()`, `dropna()`, `fillna()`, `duplicated()`, `drop_duplicates()`, `replace()`, `astype()`, `pd.to_numeric()`, `pd.to_datetime()`, `.str.strip()`, `.str.lower()`, `.str.replace()`.
#
# ---
#
# # 🟠 Challenge 4 — Création de variables et Feature Engineering
#
# ## 🎯 Objectif
#
# Créer de nouvelles informations à partir des données existantes.
#
# ## 📂 Dataset : `ventes.csv`
#
# ```csv
# vente_id,date,produit,categorie,ville,prix,quantite
# 1,2026-01-05,Laptop,Informatique,Casablanca,7000,2
# 2,2026-01-07,Souris,Informatique,Casablanca,150,10
# 3,2026-01-10,Chaise,Mobilier,Rabat,900,4
# 4,2026-01-12,Clavier,Informatique,Marrakech,400,5
# 5,2026-01-15,Bureau,Mobilier,Rabat,2500,3
# 6,2026-01-18,Écran,Informatique,Casablanca,2200,4
# 7,2026-01-20,Table,Mobilier,Tanger,1800,2
# 8,2026-01-22,Casque,Informatique,Marrakech,600,8
# 9,2026-02-03,Laptop,Informatique,Rabat,7000,1
# 10,2026-02-06,Souris,Informatique,Tanger,150,15
# 11,2026-02-09,Chaise,Mobilier,Casablanca,900,6
# 12,2026-02-14,Bureau,Mobilier,Marrakech,2500,2
# 13,2026-02-18,Écran,Informatique,Rabat,2200,3
# 14,2026-02-21,Table,Mobilier,Casablanca,1800,4
# 15,2026-02-25,Casque,Informatique,Tanger,600,10
# 16,2026-03-02,Laptop,Informatique,Marrakech,7000,2
# 17,2026-03-08,Clavier,Informatique,Casablanca,400,12
# 18,2026-03-13,Bureau,Mobilier,Tanger,2500,4
# 19,2026-03-20,Écran,Informatique,Marrakech,2200,5
# 20,2026-03-26,Chaise,Mobilier,Rabat,900,7
# ```
#
# ## 📋 Travail demandé
#
# Créer les variables suivantes.
#
# ### 1. Chiffre d'affaires
#
# Créer :
#
# ```text
# chiffre_affaires = prix × quantite
# ```
#
# ### 2. Prix avec TVA
#
# Créer une colonne `prix_avec_tva` avec une TVA de 20 %.
#
# ### 3. Catégorie de prix
#
# Créer `categorie_prix` :
#
# - CA < 1 000 → `Faible`
# - 1 000 ≤ CA ≤ 5 000 → `Moyen`
# - CA > 5 000 → `Élevé`
#
# ### 4. Analyse
#
# Créer au moins **une autre variable pertinente** à partir des données disponibles.
#
# ### Contraintes
#
# - Privilégier les opérations vectorisées.
# - Éviter les boucles lorsque cela est possible.
# - Utiliser `apply()` uniquement lorsqu'une fonction personnalisée est nécessaire.
#
# ## 🧠 Notions
#
# Vectorisation, conditions, fonctions, `apply()`, Feature Engineering.
#
# ---
#
# # 🟠 Challenge 5 — Statistiques et analyse par groupes
#
# ## 🎯 Objectif
#
# Utiliser Pandas pour réaliser une analyse statistique et commerciale.
#
# ## 📂 Dataset : `ventes.csv`
#
# Utiliser le même dataset que dans le Challenge 4.
#
# Avant l'analyse, créer la colonne :
#
# ```text
# chiffre_affaires = prix × quantite
# ```
#
# ## 📋 Travail demandé
#
# Calculer :
#
# 1. Le chiffre d'affaires total.
# 2. Le chiffre d'affaires moyen.
# 3. Le CA minimum.
# 4. Le CA maximum.
# 5. La médiane.
# 6. L'écart-type.
# 7. La variance.
# 8. Plusieurs quantiles.
#
# ### Analyse par ville
#
# 9. Calculer le CA total par ville.
# 10. Calculer le CA moyen par ville.
# 11. Compter le nombre de ventes par ville.
#
# ### Analyse par produit
#
# 12. Calculer la quantité totale vendue par produit.
# 13. Calculer le CA total par produit.
# 14. Identifier le produit générant le plus de CA.
#
# ### Analyse avancée
#
# 15. Utiliser `agg()` pour calculer plusieurs statistiques simultanément.
#
# ## 🧠 Notions
#
# `sum()`, `mean()`, `median()`, `min()`, `max()`, `std()`, `var()`, `count()`, `quantile()`, `groupby()`, `agg()`.
#
# ---
#
# # 🔵 Challenge 6 — `groupby`, `transform` et `apply`
#
# ## 🎯 Objectif
#
# Comprendre comment effectuer des calculs par groupe tout en conservant les observations originales.
#
# ## 📂 Dataset : `employes.csv`
#
# ```csv
# employe_id,nom,departement,salaire,performance
# 1,Ali,Data,6500,82
# 2,Sara,Data,7200,91
# 3,Yassine,Data,6000,75
# 4,Salma,Marketing,5800,88
# 5,Omar,Marketing,6200,79
# 6,Nadia,Marketing,7000,94
# 7,Mehdi,IT,8000,90
# 8,Hajar,IT,7500,85
# 9,Adam,IT,9000,96
# ```
#
# ## 📋 Travail demandé
#
# 1. Calculer le salaire moyen par département.
# 2. Ajouter une colonne `salaire_moyen_departement`.
# 3. Calculer l'écart entre le salaire de chaque employé et la moyenne de son département.
# 4. Créer une colonne `ecart_au_salaire_moyen`.
# 5. Calculer la performance moyenne par département.
# 6. Ajouter cette moyenne à chaque employé.
# 7. Identifier les employés ayant un salaire supérieur à la moyenne de leur département.
# 8. Calculer plusieurs statistiques par département avec `agg()`.
# 9. Utiliser `transform()` lorsque le résultat doit être conservé pour chaque ligne.
# 10. Utiliser `apply()` pour réaliser au moins une transformation personnalisée.
#
# ## 💡 Question importante
#
# Quelle est la différence entre :
#
# ```python
# df.groupby("departement").agg(...)
# ```
#
# et :
#
# ```python
# df.groupby("departement")["salaire"].transform(...)
# ```
#
# ## 🧠 Notions
#
# `groupby()`, `agg()`, `transform()`, `apply()`.
#
# ---
#
# # 🔵 Challenge 7 — Combiner plusieurs datasets
#
# ## 🎯 Objectif
#
# Combiner plusieurs sources de données comme dans un véritable projet Data.
#
# ## 📂 Dataset 1 : `clients_commandes.csv`
#
# ```csv
# client_id,nom,ville
# 1,Ali,Casablanca
# 2,Sara,Rabat
# 3,Yassine,Marrakech
# 4,Salma,Casablanca
# 5,Omar,Rabat
# 6,Nadia,Tanger
# ```
#
# ## 📂 Dataset 2 : `commandes.csv`
#
# ```csv
# commande_id,client_id,produit,montant,date
# 101,1,Laptop,7000,2026-01-10
# 102,2,Chaise,900,2026-01-12
# 103,1,Souris,150,2026-01-15
# 104,4,Bureau,2500,2026-02-01
# 105,3,Écran,2200,2026-02-05
# 106,2,Laptop,7000,2026-02-12
# 107,6,Casque,600,2026-02-20
# ```
#
# ## 📂 Dataset 3 : `produits.csv`
#
# ```csv
# produit,categorie,prix
# Laptop,Informatique,7000
# Souris,Informatique,150
# Chaise,Mobilier,900
# Bureau,Mobilier,2500
# Écran,Informatique,2200
# Casque,Informatique,600
# ```
#
# ## 📋 Travail demandé
#
# 1. Charger les trois datasets.
# 2. Identifier les colonnes permettant de relier les datasets.
# 3. Fusionner `clients_commandes` et `commandes`.
# 4. Ajouter les informations provenant de `produits`.
# 5. Tester une jointure `inner`.
# 6. Tester une jointure `left`.
# 7. Tester une jointure `right`.
# 8. Tester une jointure `outer`.
# 9. Identifier les clients n'ayant effectué aucune commande.
# 10. Utiliser `concat()` pour combiner des DataFrames.
# 11. Vérifier le résultat après chaque opération.
# 12. Vérifier qu'aucune information importante n'a été perdue.
#
# ## 🧠 Notions
#
# `merge()`, `join()`, `concat()`, clés, `inner`, `left`, `right`, `outer`.
#
# ---
#
# # 🟣 Challenge 8 — Restructuration et analyse temporelle
#
# ## 🎯 Objectif
#
# Analyser l'évolution des ventes dans le temps et restructurer les données.
#
# ## 📂 Dataset : `ventes_dates.csv`
#
# ```csv
# date,produit,categorie,ville,quantite,montant
# 2026-01-01,Laptop,Informatique,Casablanca,1,7000
# 2026-01-06,Souris,Informatique,Rabat,2,300
# 2026-01-11,Chaise,Mobilier,Marrakech,3,2700
# 2026-01-16,Bureau,Mobilier,Tanger,2,5000
# 2026-01-21,Écran,Informatique,Casablanca,2,4400
# 2026-01-26,Casque,Informatique,Rabat,5,3000
# 2026-01-31,Laptop,Informatique,Marrakech,2,14000
# 2026-02-05,Souris,Informatique,Tanger,8,1200
# 2026-02-10,Chaise,Mobilier,Casablanca,4,3600
# 2026-02-15,Bureau,Mobilier,Rabat,3,7500
# 2026-02-20,Écran,Informatique,Marrakech,2,4400
# 2026-02-25,Casque,Informatique,Tanger,6,3600
# 2026-03-02,Laptop,Informatique,Casablanca,1,7000
# 2026-03-07,Clavier,Informatique,Rabat,5,2000
# 2026-03-12,Bureau,Mobilier,Marrakech,2,5000
# 2026-03-17,Écran,Informatique,Tanger,3,6600
# 2026-03-22,Chaise,Mobilier,Casablanca,5,4500
# 2026-03-27,Casque,Informatique,Rabat,7,4200
# 2026-04-01,Laptop,Informatique,Marrakech,3,21000
# 2026-04-06,Souris,Informatique,Tanger,10,1500
# 2026-04-11,Bureau,Mobilier,Casablanca,4,10000
# 2026-04-16,Écran,Informatique,Rabat,4,8800
# 2026-04-21,Chaise,Mobilier,Marrakech,6,5400
# 2026-04-26,Casque,Informatique,Tanger,8,4800
# 2026-05-01,Laptop,Informatique,Casablanca,2,14000
# 2026-05-06,Souris,Informatique,Rabat,12,1800
# 2026-05-11,Bureau,Mobilier,Marrakech,3,7500
# 2026-05-16,Écran,Informatique,Tanger,2,4400
# 2026-05-21,Chaise,Mobilier,Casablanca,7,6300
# 2026-05-26,Casque,Informatique,Rabat,9,5400
# 2026-05-31,Laptop,Informatique,Marrakech,2,14000
# 2026-06-05,Clavier,Informatique,Tanger,8,3200
# 2026-06-10,Bureau,Mobilier,Casablanca,5,12500
# 2026-06-15,Écran,Informatique,Rabat,3,6600
# 2026-06-20,Chaise,Mobilier,Marrakech,4,3600
# 2026-06-25,Casque,Informatique,Tanger,10,6000
# 2026-06-30,Laptop,Informatique,Casablanca,2,14000
# ```
#
# ## 📋 Travail demandé
#
# 1. Convertir `date` en datetime.
# 2. Extraire l'année.
# 3. Extraire le mois.
# 4. Extraire le jour.
# 5. Extraire le jour de la semaine.
# 6. Extraire le trimestre.
# 7. Calculer le CA par mois.
# 8. Calculer le CA par trimestre.
# 9. Identifier le meilleur mois.
# 10. Analyser l'évolution des ventes.
# 11. Créer une `pivot_table`.
# 12. Créer une `crosstab`.
# 13. Utiliser `resample()` pour effectuer une analyse temporelle.
# 14. Comparer les ventes entre les différentes villes au fil du temps.
#
# ## 🧠 Notions
#
# `pd.to_datetime()`, `.dt.year`, `.dt.month`, `.dt.day`, `.dt.day_name()`, `.dt.quarter`, `resample()`, `pivot_table()`, `crosstab()`.
#
# ---
#
# # 🔴 Challenge 9 — Préparation des données pour le Machine Learning
#
# ## 🎯 Objectif
#
# Préparer un dataset Pandas afin de pouvoir ensuite l'utiliser avec Scikit-learn.
#
# ## 📂 Dataset : `clients_ml.csv`
#
# ```csv
# client_id,age,sexe,ville,profession,salaire,anciennete,nombre_commandes,depenses,churn
# 1,25,M,Casablanca,Ingénieur,5000,2,8,4200,0
# 2,31,F,Rabat,Comptable,6500,5,15,9000,0
# 3,28,M,Marrakech,Développeur,4500,3,4,1800,1
# 4,35,F,Casablanca,Manager,8000,7,20,15000,0
# 5,,M,Rabat,Commercial,9000,10,25,21000,0
# 6,29,F,Tanger,Analyste,5200,4,7,3500,1
# 7,38,M,CASABLANCA,Ingénieur,7500,8,18,12000,0
# 8,N/A,F,Marrakech,Développeur,4800,2,5,2200,1
# 9,45,M,Rabat,Directeur,10000,12,30,30000,0
# 10,33,F,Tanger,Analyste,6200 DH,6,9,5000,1
# 11,27,M,Casablanca,Commercial,4700,1,3,1200,1
# 12,52,F,Rabat,Manager,11000,15,28,27000,0
# 13,24,M,Marrakech,Développeur,4300,1,2,900,1
# 14,40,F,Casablanca,Ingénieur,8500,9,22,17000,0
# 14,40,F,Casablanca,Ingénieur,8500,9,22,17000,0
# 15,36,M,Tanger,Commercial,5800,5,10,6200,1
# 16,30,F,Rabat,Analyste,6100,4,12,7600,0
# 17,67,M,Casablanca,Directeur,12500,20,35,50000,0
# 18,26,F,Marrakech,Commercial,4600,2,1,500,1
# 19,34,M,Rabat,Ingénieur,7200,6,16,11000,0
# 20,39,F,Tanger,Manager,7800,8,19,14500,0
# ```
#
# ## 📋 Travail demandé
#
# ### Étape 1 — Exploration
#
# 1. Explorer le dataset.
# 2. Vérifier les dimensions.
# 3. Vérifier les types.
# 4. Identifier les valeurs manquantes.
# 5. Identifier les doublons.
#
# ### Étape 2 — Nettoyage
#
# 6. Traiter les valeurs manquantes.
# 7. Traiter les doublons.
# 8. Corriger les types.
# 9. Standardiser les catégories.
# 10. Identifier les valeurs aberrantes.
#
# ### Étape 3 — Feature Engineering
#
# 11. Créer au moins une nouvelle variable pertinente.
# 12. Justifier votre choix.
#
# ### Étape 4 — Encodage
#
# 13. Identifier les variables catégorielles.
# 14. Encoder les variables catégorielles avec `pd.get_dummies()`.
#
# ### Étape 5 — Préparation ML
#
# 15. Identifier les variables explicatives.
# 16. Identifier la variable cible `churn`.
# 17. Construire `X`.
# 18. Construire `y`.
# 19. Vérifier les dimensions de `X` et `y`.
# 20. Vérifier que les données finales sont exploitables par un modèle de Machine Learning.
#
# ### Exemple
#
# ```python
# features = [
#     "age",
#     "salaire",
#     "anciennete",
#     "nombre_commandes",
#     "depenses"
# ]
#
# X = df[features]
# y = df["churn"]
# ```
#
# ## 🧠 Notions
#
# Preprocessing, outliers, encodage, features, target, Feature Engineering, `X`, `y`, `pd.get_dummies()`.
#
# > ⚠️ Dans un véritable projet Machine Learning, les étapes de preprocessing sont généralement intégrées dans des `Pipeline` et `ColumnTransformer` de Scikit-learn.
#
# ---
#
# # 🔴 Challenge 10 — Projet final : Analyse et préparation d'un dataset réel
#
# ## 🎯 Objectif
#
# Réaliser un projet complet de Data Science en utilisant les compétences acquises dans les challenges précédents.
#
# ## 📂 Dataset : `clients_final.csv`
#
# ```csv
# client_id,age,sexe,ville,profession,salaire,anciennete,nombre_commandes,depenses_totales,derniere_commande,satisfaction,churn
# 1,25,M,Casablanca,Ingénieur,5000,2,8,4200,2026-05-10,8,0
# 2,31,F,Rabat,Comptable,6500,5,15,9000,2026-05-15,9,0
# 3,28,M,Marrakech,Développeur,4500,3,4,1800,2026-03-10,5,1
# 4,35,F,Casablanca,Manager,8000,7,20,15000,2026-06-01,9,0
# 5,,M,Rabat,Commercial,9000,10,25,21000,2026-05-28,8,0
# 6,29,F,Tanger,Analyste,5200,4,7,3500,2026-02-20,4,1
# 7,38,M,CASABLANCA,Ingénieur,7500,8,18,12000,2026-05-20,7,0
# 8,N/A,F,Marrakech,Développeur,4800,2,5,2200,2026-01-15,3,1
# 9,45,M,Rabat,Directeur,10000,12,30,30000,2026-06-10,10,0
# 10,33,F, Tanger ,Analyste,6200 DH,6,9,5000,2026-03-18,5,1
# 11,27,M,Casablanca,Commercial,4700,1,3,1200,2026-01-20,4,1
# 12,52,F,Rabat,Manager,11000,15,28,27000,2026-06-15,9,0
# 13,24,M,Marrakech,Développeur,4300,1,2,900,2026-02-12,3,1
# 14,40,F,Casablanca,Ingénieur,8500,9,22,17000,2026-06-05,8,0
# 14,40,F,Casablanca,Ingénieur,8500,9,22,17000,2026-06-05,8,0
# 15,36,M,Tanger,Commercial,5800,5,10,6200,2026-04-10,6,1
# 16,30,F,Rabat,Analyste,6100,4,12,7600,2026-05-01,7,0
# 17,67,M,Casablanca,Directeur,12500,20,35,50000,2026-06-20,10,0
# 18,26,F,Marrakech,Commercial,4600,2,1,500,2026-01-05,2,1
# 19,34,M,Rabat,Ingénieur,7200,6,16,11000,2026-05-25,8,0
# 20,39,F,Tanger,Manager,7800,8,19,14500,2026-06-12,7,0
# 21,48,M,Casablanca,Commercial,6800,11,14,9800,2026-04-18,6,1
# 22,23,F,Rabat,Développeur,4200,1,2,800,2026-02-05,3,1
# 23,41,M,Marrakech,Ingénieur,8200,9,21,16000,2026-06-08,9,0
# 24,32,F,Tanger,Analyste,5600,3,11,6800,2026-04-22,6,1
# 25,37,M,Casablanca,Manager,7900,7,17,13000,2026-05-30,8,0
# ```
#
# ---
#
# ## 📋 Mission
#
# Vous devez réaliser vous-même l'ensemble du processus.
#
# ```text
# DATASET BRUT
#      ↓
# EXPLORATION
#      ↓
# NETTOYAGE
#      ↓
# VALEURS MANQUANTES
#      ↓
# DOUBLONS
#      ↓
# TYPES
#      ↓
# OUTLIERS
#      ↓
# FEATURE ENGINEERING
#      ↓
# ANALYSE EXPLORATOIRE
#      ↓
# GROUPBY
#      ↓
# ANALYSE TEMPORELLE
#      ↓
# ENCODAGE
#      ↓
# X / y
#      ↓
# DATASET PRÊT POUR LE MACHINE LEARNING
# ```
#
# > **Important :** contrairement aux challenges précédents, aucune recette détaillée ne vous est donnée. Vous devez choisir vous-mêmes les étapes nécessaires.
#
# ---
#
# ## 🔎 Partie 1 — Exploration
#
# Répondre notamment aux questions suivantes :
#
# 1. Combien de clients sont présents ?
# 2. Combien de variables possède le dataset ?
# 3. Quel est l'âge moyen ?
# 4. Quel est le salaire moyen ?
# 5. Quelles sont les villes représentées ?
# 6. Combien de clients appartiennent à chaque ville ?
# 7. Quelles sont les variables numériques ?
# 8. Quelles sont les variables catégorielles ?
# 9. Existe-t-il des valeurs manquantes ?
# 10. Existe-t-il des doublons ?
#
# ---
#
# ## 🧹 Partie 2 — Nettoyage
#
# 11. Nettoyer les valeurs manquantes.
# 12. Supprimer les doublons.
# 13. Standardiser les villes.
# 14. Corriger les types incorrects.
# 15. Nettoyer les salaires.
# 16. Vérifier les dates.
# 17. Identifier les éventuelles valeurs aberrantes.
# 18. Vérifier la cohérence du dataset après nettoyage.
#
# ---
#
# ## 📊 Partie 3 — Analyse
#
# Analyser notamment :
#
# 19. La ville ayant le plus de clients.
# 20. La ville générant le plus de dépenses.
# 21. Les clients qui dépensent le plus.
# 22. Le nombre moyen de commandes par ville.
# 23. Les dépenses moyennes par ville.
# 24. Les statistiques de satisfaction par ville.
# 25. Les différentes statistiques selon le sexe ou la profession.
#
# ---
#
# ## 📉 Partie 4 — Analyse du churn
#
# La colonne `churn` indique si le client a quitté le service :
#
# ```text
# 0 → client conservé
# 1 → client ayant quitté le service
# ```
#
# Analyser :
#
# 26. Le taux global de churn.
# 27. Le churn selon l'âge.
# 28. Le churn selon le salaire.
# 29. Le churn selon la ville.
# 30. Le churn selon la profession.
# 31. Le churn selon le nombre de commandes.
# 32. Le churn selon les dépenses.
# 33. Le churn selon la satisfaction.
#
# Formuler quelques conclusions à partir des résultats obtenus.
#
# ---
#
# ## 🤖 Partie 5 — Préparation Machine Learning
#
# Déterminer :
#
# 34. Les colonnes à conserver.
# 35. Les colonnes à supprimer.
# 36. Les variables à encoder.
# 37. La stratégie de traitement des valeurs manquantes.
# 38. La stratégie de traitement des outliers.
# 39. Les nouvelles variables éventuellement utiles.
# 40. Les variables explicatives `X`.
# 41. La variable cible `y`.
# 42. Les dimensions finales de `X` et `y`.
# 43. Vérifier que le dataset final est prêt à être utilisé avec Scikit-learn.
#
# ---
#
# # 🏆 Compétences attendues
#
# À la fin de ces 10 challenges, vous devez être capables de :
#
# - ✅ Charger et explorer un dataset.
# - ✅ Comprendre la structure d'un DataFrame.
# - ✅ Sélectionner et filtrer des données.
# - ✅ Utiliser les conditions booléennes.
# - ✅ Nettoyer des données réelles.
# - ✅ Gérer les valeurs manquantes.
# - ✅ Gérer les doublons.
# - ✅ Corriger les types.
# - ✅ Manipuler les chaînes de caractères.
# - ✅ Manipuler les dates.
# - ✅ Créer de nouvelles variables.
# - ✅ Utiliser la vectorisation.
# - ✅ Utiliser `apply()` lorsque nécessaire.
# - ✅ Réaliser des statistiques descriptives.
# - ✅ Utiliser `groupby()`.
# - ✅ Comprendre `agg()` et `transform()`.
# - ✅ Combiner plusieurs datasets avec `merge()` et `concat()`.
# - ✅ Restructurer les données avec `pivot_table()`.
# - ✅ Utiliser `crosstab()`.
# - ✅ Réaliser des analyses temporelles.
# - ✅ Encoder des variables catégorielles.
# - ✅ Préparer `X` et `y`.
# - ✅ Préparer un dataset pour le Machine Learning.
#
# ---
#
# # 🚀 Objectif final
#
# > **Être capable de prendre un dataset réel, comprendre sa structure, identifier ses problèmes, le nettoyer, l'analyser, créer de nouvelles variables et le préparer pour un projet de Machine Learning.**
