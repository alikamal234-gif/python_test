# %% [markdown]
# # 📊 Série de Challenges — Matplotlib & Seaborn
#
# ## 🎯 Objectif général
#
# Cette série de challenges a pour objectif de vous apprendre à **visualiser et analyser des données** avec :
#
# - **Matplotlib** : création et personnalisation de graphiques.
# - **Seaborn** : visualisation statistique et analyse exploratoire.
# - **Pandas** : préparation et manipulation des données avant leur visualisation.
#
# La progression est volontairement graduelle :
#
# ```text
# Matplotlib
#    ↓
# Graphiques simples
#    ↓
# Personnalisation
#    ↓
# Plusieurs graphiques
#    ↓
# Analyse exploratoire
#    ↓
# Seaborn
#    ↓
# Relations entre variables
#    ↓
# Analyse catégorielle
#    ↓
# Corrélations
#    ↓
# Projet final
# ```
#
# ---
#
# # 🟢 Challenge 1 — Premier graphique avec Matplotlib
#
# ## 🎯 Objectif
#
# Découvrir la création d'un graphique simple avec Matplotlib.
#
# ## 📁 Dataset
#
# **Fichier :** `temperature.csv`
#
# ```csv
# jour,temperature
# Lundi,18
# Mardi,20
# Mercredi,19
# Jeudi,22
# Vendredi,24
# Samedi,26
# Dimanche,25
# ```
#
# ## 📋 Travail demandé
#
# 1. Charger le dataset avec Pandas.
# 2. Afficher les premières lignes.
# 3. Créer un graphique représentant l'évolution de la température pendant la semaine.
# 4. Utiliser un graphique en ligne.
# 5. Ajouter un titre.
# 6. Ajouter un nom à l'axe X.
# 7. Ajouter un nom à l'axe Y.
# 8. Ajouter une grille.
# 9. Afficher le graphique.
#
# ## 💡 Notions à utiliser
#
# ```python
# import matplotlib.pyplot as plt
#
# plt.plot()
# plt.title()
# plt.xlabel()
# plt.ylabel()
# plt.grid()
# plt.show()
# ```
#
# ---
#
# # 🟢 Challenge 2 — Graphique en barres
#
# ## 🎯 Objectif
#
# Comparer plusieurs catégories à l'aide d'un graphique en barres.
#
# ## 📁 Dataset
#
# **Fichier :** `ventes_villes.csv`
#
# ```csv
# ville,ventes
# Casablanca,45000
# Rabat,38000
# Marrakech,29000
# Tanger,22000
# Fes,18000
# Agadir,25000
# ```
#
# ## 📋 Travail demandé
#
# 1. Charger le dataset.
# 2. Afficher les données.
# 3. Créer un graphique en barres représentant les ventes par ville.
# 4. Ajouter un titre.
# 5. Nommer les axes.
# 6. Modifier la taille du graphique.
# 7. Ajouter une grille.
# 8. Afficher la valeur de chaque barre.
#
# ## ❓ Question
#
# Quelle ville réalise le plus grand volume de ventes ?
#
# ## 💡 Notions à utiliser
#
# ```python
# plt.bar()
# plt.text()
# plt.figure()
# plt.grid()
# ```
#
# ---
#
# # 🟢 Challenge 3 — Histogramme et distribution
#
# ## 🎯 Objectif
#
# Comprendre comment observer la distribution d'une variable numérique.
#
# ## 📁 Dataset
#
# **Fichier :** `notes_etudiants.csv`
#
# ```csv
# etudiant,note
# Etudiant1,12
# Etudiant2,15
# Etudiant3,8
# Etudiant4,17
# Etudiant5,13
# Etudiant6,10
# Etudiant7,14
# Etudiant8,16
# Etudiant9,9
# Etudiant10,11
# Etudiant11,18
# Etudiant12,13
# Etudiant13,15
# Etudiant14,7
# Etudiant15,12
# Etudiant16,14
# Etudiant17,16
# Etudiant18,10
# Etudiant19,11
# Etudiant20,17
# Etudiant21,13
# Etudiant22,15
# Etudiant23,9
# Etudiant24,18
# Etudiant25,12
# ```
#
# ## 📋 Travail demandé
#
# 1. Charger le dataset.
# 2. Créer un histogramme des notes.
# 3. Choisir un nombre de classes pertinent.
# 4. Ajouter un titre.
# 5. Ajouter les noms des axes.
# 6. Ajouter une grille.
# 7. Observer la distribution des notes.
#
# ## ❓ Questions
#
# - Dans quelle zone se trouvent la majorité des notes ?
# - Les notes sont-elles plutôt faibles, moyennes ou élevées ?
# - Observe-t-on des valeurs très faibles ou très élevées ?
#
# ## 💡 Notion à utiliser
#
# ```python
# plt.hist()
# ```
#
# ---
#
# # 🟢 Challenge 4 — Relation entre deux variables
#
# ## 🎯 Objectif
#
# Utiliser un **scatter plot** pour étudier la relation entre deux variables numériques.
#
# ## 📁 Dataset
#
# **Fichier :** `heures_notes.csv`
#
# ```csv
# etudiant,heures_etude,note
# E1,2,9
# E2,3,10
# E3,4,11
# E4,5,12
# E5,6,13
# E6,7,14
# E7,8,15
# E8,9,16
# E9,10,17
# E10,11,18
# E11,3,11
# E12,5,13
# E13,7,15
# E14,9,17
# E15,4,12
# E16,6,14
# E17,8,16
# E18,10,18
# E19,2,8
# E20,12,19
# ```
#
# ## 📋 Travail demandé
#
# 1. Charger le dataset.
# 2. Créer un scatter plot.
# 3. Mettre `heures_etude` sur l'axe X.
# 4. Mettre `note` sur l'axe Y.
# 5. Ajouter un titre.
# 6. Ajouter les noms des axes.
# 7. Ajouter une grille.
# 8. Observer la relation entre les deux variables.
#
# ## ❓ Questions
#
# - Existe-t-il une relation entre le nombre d'heures d'étude et la note ?
# - Cette relation semble-t-elle positive ou négative ?
# - Que peut-on observer visuellement ?
#
# ## 💡 Notion à utiliser
#
# ```python
# plt.scatter()
# ```
#
# ---
#
# # 🟡 Challenge 5 — Plusieurs graphiques avec Matplotlib
#
# ## 🎯 Objectif
#
# Apprendre à afficher plusieurs visualisations dans une même figure.
#
# ## 📁 Dataset
#
# **Fichier :** `entreprise.csv`
#
# ```csv
# employe,departement,salaire,experience,performance
# Ali,Data,6500,2,75
# Sara,Data,7200,4,88
# Yassine,Data,6000,3,70
# Salma,Marketing,5800,5,82
# Omar,Marketing,6200,6,78
# Nadia,Marketing,7000,8,91
# Mehdi,IT,8000,7,90
# Hajar,IT,7500,5,85
# Adam,IT,9000,10,95
# Imane,Data,6800,6,84
# ```
#
# ## 📋 Travail demandé
#
# Créer une figure contenant **4 graphiques** :
#
# ### Graphique 1
# Représenter le salaire de chaque employé avec un graphique en barres.
#
# ### Graphique 2
# Représenter la distribution des salaires avec un histogramme.
#
# ### Graphique 3
# Étudier la relation entre l'expérience et la performance avec un scatter plot.
#
# ### Graphique 4
# Comparer les salaires moyens des différents départements.
#
# Utiliser :
#
# ```python
# plt.subplots()
# ```
#
# ## ❓ Questions
#
# - Quel département semble avoir les salaires les plus élevés ?
# - Existe-t-il une relation entre expérience et performance ?
# - Quelle visualisation est la plus adaptée pour chaque analyse ?
#
# ## 💡 Notions à utiliser
#
# ```python
# plt.subplots()
# fig
# ax
# ax.bar()
# ax.hist()
# ax.scatter()
# ```
#
# ---
#
# # 🟡 Challenge 6 — Première découverte de Seaborn
#
# ## 🎯 Objectif
#
# Découvrir Seaborn et réaliser des visualisations statistiques simples.
#
# ## 📁 Dataset
#
# **Fichier :** `clients.csv`
#
# ```csv
# client_id,age,sexe,ville,salaire
# 1,25,M,Casablanca,5000
# 2,31,F,Rabat,6500
# 3,28,M,Marrakech,4500
# 4,35,F,Casablanca,8000
# 5,42,M,Rabat,9000
# 6,29,F,Tanger,5200
# 7,38,M,Casablanca,7500
# 8,26,F,Marrakech,4800
# 9,45,M,Rabat,10000
# 10,33,F,Tanger,6200
# 11,27,M,Casablanca,4700
# 12,40,F,Rabat,8500
# ```
#
# ## 📋 Travail demandé
#
# Réaliser les visualisations suivantes :
#
# ### 1. Distribution de l'âge
#
# Utiliser :
#
# ```python
# sns.histplot()
# ```
#
# ### 2. Nombre de clients par ville
#
# Utiliser :
#
# ```python
# sns.countplot()
# ```
#
# ### 3. Distribution des salaires
#
# Utiliser :
#
# ```python
# sns.boxplot()
# ```
#
# ### 4. Comparaison des salaires selon le sexe
#
# Utiliser un graphique adapté.
#
# Pour chaque graphique :
#
# - ajouter un titre ;
# - nommer les axes ;
# - rendre la visualisation lisible.
#
# ## 💡 Import
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```
#
# ## 💡 Notions à découvrir
#
# ```python
# sns.histplot()
# sns.countplot()
# sns.boxplot()
# ```
#
# ---
#
# # 🟡 Challenge 7 — Relations entre variables avec Seaborn
#
# ## 🎯 Objectif
#
# Analyser les relations entre plusieurs variables numériques avec Seaborn.
#
# ## 📁 Dataset
#
# **Fichier :** `clients_depenses.csv`
#
# ```csv
# client_id,age,salaire,nombre_commandes,depenses
# 1,25,5000,8,4200
# 2,31,6500,15,9000
# 3,28,4500,4,1800
# 4,35,8000,20,15000
# 5,42,9000,25,21000
# 6,29,5200,7,3500
# 7,38,7500,18,12000
# 8,26,4800,5,2200
# 9,45,10000,30,30000
# 10,33,6200,9,5000
# 11,27,4700,3,1200
# 12,40,8500,22,17000
# 13,24,4300,2,900
# 14,36,5800,10,6200
# 15,30,6100,12,7600
# ```
#
# ## 📋 Travail demandé
#
# ### Analyse 1
#
# Étudier la relation entre :
#
# ```text
# salaire ↔ dépenses
# ```
#
# Utiliser :
#
# ```python
# sns.scatterplot()
# ```
#
# ### Analyse 2
#
# Étudier la relation entre :
#
# ```text
# nombre_commandes ↔ dépenses
# ```
#
# ### Analyse 3
#
# Étudier la relation entre :
#
# ```text
# âge ↔ salaire
# ```
#
# ### Analyse 4
#
# Utiliser `regplot()` pour ajouter une droite de tendance.
#
# ### Analyse 5
#
# Utiliser `pairplot()` pour explorer plusieurs relations simultanément.
#
# ## ❓ Questions
#
# Pour chaque relation :
#
# - Existe-t-il une relation entre les variables ?
# - La relation semble-t-elle positive ou négative ?
# - Existe-t-il des valeurs qui semblent particulières ?
#
# ## 💡 Notions à utiliser
#
# ```python
# sns.scatterplot()
# sns.regplot()
# sns.pairplot()
# ```
#
# ---
#
# # 🟠 Challenge 8 — Analyse catégorielle avec Seaborn
#
# ## 🎯 Objectif
#
# Comparer des groupes à l'aide de différentes visualisations statistiques.
#
# ## 📁 Dataset
#
# **Fichier :** `employes_performance.csv`
#
# ```csv
# employe,departement,sexe,salaire,performance
# Ali,Data,M,6500,75
# Sara,Data,F,7200,88
# Yassine,Data,M,6000,70
# Salma,Marketing,F,5800,82
# Omar,Marketing,M,6200,78
# Nadia,Marketing,F,7000,91
# Mehdi,IT,M,8000,90
# Hajar,IT,F,7500,85
# Adam,IT,M,9000,95
# Imane,Data,F,6800,84
# Karim,IT,M,8500,92
# Lina,Marketing,F,6400,87
# ```
#
# ## 📋 Travail demandé
#
# Réaliser les analyses suivantes :
#
# ### Analyse 1
#
# Comparer le salaire moyen par département.
#
# ```python
# sns.barplot()
# ```
#
# ### Analyse 2
#
# Observer la distribution des salaires selon le département.
#
# ```python
# sns.boxplot()
# ```
#
# ### Analyse 3
#
# Comparer les performances selon le département.
#
# ### Analyse 4
#
# Comparer les salaires selon le sexe.
#
# ### Analyse 5
#
# Comparer les performances selon le sexe avec un `violinplot()`.
#
# ### Analyse 6
#
# Utiliser `hue` lorsque cela est pertinent pour ajouter une deuxième dimension d'analyse.
#
# ## ❓ Questions
#
# - Quel département possède les salaires les plus élevés ?
# - Quel département semble avoir les meilleures performances ?
# - Observe-t-on des différences entre les hommes et les femmes ?
# - Pourquoi utiliser un boxplot plutôt qu'un simple graphique en barres ?
#
# ## 💡 Notions à utiliser
#
# ```python
# sns.barplot()
# sns.boxplot()
# sns.violinplot()
# hue=
# ```
#
# ---
#
# # 🟠 Challenge 9 — Corrélation et Heatmap
#
# ## 🎯 Objectif
#
# Comprendre les corrélations entre plusieurs variables numériques et les représenter graphiquement.
#
# ## 📁 Dataset
#
# **Fichier :** `clients_correlation.csv`
#
# ```csv
# client_id,age,salaire,anciennete,nombre_commandes,depenses,satisfaction
# 1,25,5000,2,8,4200,8
# 2,31,6500,5,15,9000,9
# 3,28,4500,3,4,1800,5
# 4,35,8000,7,20,15000,9
# 5,42,9000,10,25,21000,8
# 6,29,5200,4,7,3500,4
# 7,38,7500,8,18,12000,7
# 8,26,4800,2,5,2200,3
# 9,45,10000,12,30,30000,10
# 10,33,6200,6,9,5000,5
# 11,27,4700,1,3,1200,4
# 12,40,8500,9,22,17000,9
# 13,24,4300,1,2,900,3
# 14,36,5800,5,10,6200,6
# 15,30,6100,4,12,7600,7
# ```
#
# ## 📋 Travail demandé
#
# 1. Charger le dataset.
# 2. Sélectionner les variables numériques.
# 3. Calculer la matrice de corrélation avec Pandas.
# 4. Afficher la matrice.
# 5. Créer une heatmap avec Seaborn.
# 6. Afficher les valeurs des corrélations.
# 7. Ajouter un titre.
# 8. Identifier les corrélations fortes.
# 9. Identifier les variables qui semblent fortement liées aux dépenses.
#
# ## 💡 Notions à utiliser
#
# ```python
# df.corr(numeric_only=True)
# ```
#
# et :
#
# ```python
# sns.heatmap()
# ```
#
# avec notamment :
#
# ```python
# annot=True
# ```
#
# ## ❓ Questions
#
# - Quelles variables sont fortement corrélées ?
# - Quelles variables sont positivement corrélées ?
# - Existe-t-il des corrélations négatives ?
# - Quelle variable semble la plus liée aux dépenses ?
#
# ---
#
# # 🔴 Challenge 10 — Projet final : Analyse visuelle complète
#
# ## 🎯 Objectif
#
# Réaliser une **analyse exploratoire visuelle complète** d'un dataset de clients en utilisant **Matplotlib et Seaborn**.
#
# > ⚠️ Contrairement aux challenges précédents, aucune recette détaillée n'est donnée.
# > Vous devez choisir vous-mêmes les visualisations les plus adaptées aux différentes analyses.
#
# ---
#
# ## 📁 Dataset
#
# **Fichier :** `clients_final.csv`
#
# ```csv
# client_id,age,sexe,ville,profession,salaire,anciennete,nombre_commandes,depenses,satisfaction,churn
# 1,25,M,Casablanca,Ingenieur,5000,2,8,4200,8,0
# 2,31,F,Rabat,Comptable,6500,5,15,9000,9,0
# 3,28,M,Marrakech,Developpeur,4500,3,4,1800,5,1
# 4,35,F,Casablanca,Manager,8000,7,20,15000,9,0
# 5,42,M,Rabat,Commercial,9000,10,25,21000,8,0
# 6,29,F,Tanger,Analyste,5200,4,7,3500,4,1
# 7,38,M,Casablanca,Ingenieur,7500,8,18,12000,7,0
# 8,26,F,Marrakech,Developpeur,4800,2,5,2200,3,1
# 9,45,M,Rabat,Directeur,10000,12,30,30000,10,0
# 10,33,F,Tanger,Analyste,6200,6,9,5000,5,1
# 11,27,M,Casablanca,Commercial,4700,1,3,1200,4,1
# 12,40,F,Rabat,Manager,8500,9,22,17000,9,0
# 13,24,M,Marrakech,Developpeur,4300,1,2,900,3,1
# 14,36,F,Casablanca,Ingenieur,8500,9,22,17000,8,0
# 15,30,M,Tanger,Commercial,5800,5,10,6200,6,1
# 16,32,F,Rabat,Analyste,6100,4,12,7600,7,0
# 17,52,M,Casablanca,Directeur,12500,15,35,50000,10,0
# 18,26,F,Marrakech,Commercial,4600,2,1,500,2,1
# 19,34,M,Rabat,Ingenieur,7200,6,16,11000,8,0
# 20,39,F,Tanger,Manager,7800,8,19,14500,7,0
# 21,48,M,Casablanca,Commercial,6800,11,14,9800,6,1
# 22,23,F,Rabat,Developpeur,4200,1,2,800,3,1
# 23,41,M,Marrakech,Ingenieur,8200,9,21,16000,9,0
# 24,32,F,Tanger,Analyste,5600,3,11,6800,6,1
# 25,37,M,Casablanca,Manager,7900,7,17,13000,8,0
# ```
#
# ---
#
# # 📋 Mission
#
# Vous devez réaliser une **analyse exploratoire visuelle complète**.
#
# Vous pouvez utiliser :
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# ---
#
# ## 1️⃣ Analyse des variables numériques
#
# Étudier visuellement :
#
# - `age`
# - `salaire`
# - `anciennete`
# - `nombre_commandes`
# - `depenses`
# - `satisfaction`
#
# Choisir les graphiques adaptés.
#
# Exemples :
#
# ```text
# Histogramme
# Boxplot
# Barplot
# ```
#
# ---
#
# ## 2️⃣ Analyse des variables catégorielles
#
# Analyser :
#
# - `sexe`
# - `ville`
# - `profession`
#
# Choisir les visualisations adaptées.
#
# ---
#
# ## 3️⃣ Analyse des relations
#
# Explorer différentes relations entre variables.
#
# Par exemple :
#
# ```text
# salaire ↔ depenses
# nombre_commandes ↔ depenses
# age ↔ salaire
# satisfaction ↔ depenses
# ```
#
# Utiliser les graphiques adaptés.
#
# ---
#
# ## 4️⃣ Analyse du churn
#
# La variable :
#
# ```text
# churn
# ```
#
# indique si le client a quitté l'entreprise :
#
# ```text
# 0 → Client conservé
# 1 → Client ayant quitté l'entreprise
# ```
#
# Étudier visuellement le churn selon :
#
# - la ville ;
# - le sexe ;
# - la profession ;
# - l'âge ;
# - le salaire ;
# - le nombre de commandes ;
# - les dépenses ;
# - la satisfaction.
#
# ---
#
# ## 5️⃣ Analyse des corrélations
#
# Créer une matrice de corrélation et la représenter sous forme de **heatmap**.
#
# Identifier les relations importantes entre les variables numériques.
#
# ---
#
# ## 6️⃣ Comparaison des clients
#
# Comparer les caractéristiques des clients :
#
# ```text
# churn = 0
# ```
#
# avec :
#
# ```text
# churn = 1
# ```
#
# Chercher à déterminer s'il existe des différences importantes entre les deux groupes.
#
# ---
#
# ## 7️⃣ Synthèse
#
# À la fin de votre analyse, rédiger **5 à 10 observations** basées sur vos visualisations.
#
# Exemples de questions :
#
# - Quelle ville possède le plus de clients ?
# - Quelle ville génère le plus de dépenses ?
# - Quel profil de client semble le plus dépensier ?
# - Existe-t-il une relation entre salaire et dépenses ?
# - Existe-t-il une relation entre nombre de commandes et dépenses ?
# - Quels facteurs semblent associés au churn ?
# - Quelle variable semble la plus corrélée aux dépenses ?
# - Les clients ayant un churn ont-ils une satisfaction différente ?
# - Quels graphiques vous semblent les plus pertinents ?
#
# ---
#
# # 🎯 Compétences attendues à la fin des 10 challenges
#
# À la fin de cette série, vous devez être capables de :
#
# ### Matplotlib
#
# - créer un graphique en ligne ;
# - créer un graphique en barres ;
# - créer un histogramme ;
# - créer un scatter plot ;
# - personnaliser un graphique ;
# - créer plusieurs graphiques avec `subplots()`.
#
# ### Seaborn
#
# - utiliser `histplot()` ;
# - utiliser `countplot()` ;
# - utiliser `barplot()` ;
# - utiliser `boxplot()` ;
# - utiliser `violinplot()` ;
# - utiliser `scatterplot()` ;
# - utiliser `regplot()` ;
# - utiliser `pairplot()` ;
# - utiliser `heatmap()` ;
# - utiliser `hue`.
#
# ### Data Visualization
#
# Vous devez également être capables de répondre à une question importante :
#
# > **Quel type de graphique dois-je utiliser pour analyser mes données ?**
#
# Et surtout :
#
# > **Comment passer d'un graphique à une interprétation des données ?**
#
# ---
#
# # 📁 Organisation recommandée
#
# ```text
# matplotlib-seaborn-challenges/
# │
# ├── datasets/
# │   ├── temperature.csv
# │   ├── ventes_villes.csv
# │   ├── notes_etudiants.csv
# │   ├── heures_notes.csv
# │   ├── entreprise.csv
# │   ├── clients.csv
# │   ├── clients_depenses.csv
# │   ├── employes_performance.csv
# │   ├── clients_correlation.csv
# │   └── clients_final.csv
# │
# ├── challenge_01.ipynb
# ├── challenge_02.ipynb
# ├── challenge_03.ipynb
# ├── challenge_04.ipynb
# ├── challenge_05.ipynb
# ├── challenge_06.ipynb
# ├── challenge_07.ipynb
# ├── challenge_08.ipynb
# ├── challenge_09.ipynb
# └── challenge_10.ipynb
# ```
#
# # 🚀 Bonne exploration des données !
